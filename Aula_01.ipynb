# %% [markdown]
# <a href="https://colab.research.google.com/github/strawndri/imersao-dados-2021/blob/main/Aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Aula 01

# %% [markdown]
# - Importando Pandas e Matplotlib
# - Guardando os dados na variável **url_dados**
# - O arquivo precisa ser descompactado e lido

# %%
import pandas as pd
import matplotlib.pyplot as plt

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.head() # mostra as 5 primeiras linhas

# %% [markdown]
# ### pd.unique() - mostra os únicos valores

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %%
dados['dose'].unique()
# Out:
# array(['D1', 'D2'], dtype=object)

# %%
dados['droga'].unique()
# Out:
# array(['b68db1d53', 'df89a8e5a', '18bb41b2c', ..., '573c787a2',
#        'b2fe3eca7', 'dd4a96d16'], dtype=object)

# %% [markdown]
# ### Gráficos

# %%
dados['tratamento'].value_counts().plot.pie()

# %%
dados['tempo'].value_counts().plot.bar()

# %% [markdown]
# ### Filtrando dados

# %%
dados_filtrados = dados[dados['g-0'] > 0]
dados_filtrados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 6  id_001bd861f  com_droga     24   D2  ...  2.4670  0.0357  0.1351 -0.3179
# 7  id_0020d0484  com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
#
# [5 rows x 877 columns]

# %% [markdown]
# ### Desafio 01 : Por que a classe tratamento é tão desbalanceada?

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %% [markdown]
# Porque a maioria das colônias de células receberam algum tipo de droga para a análise.

# %% [markdown]
# ### Desafio 02: Plotar as 5 últimas linhas da table.

# %%
dados.tail() # mostra as 5 últimas linhas

# %% [markdown]
# ### Desafio 03: Proporção das classes de tratamento.

# %%
dados['tratamento'].value_counts(normalize=True) * 100
# Out:
# com_droga       92.164273
# com_controle     7.835727
# Name: tratamento, dtype: float64

# %% [markdown]
# ### Desafio 04: Quantas drogas foram investigadas?

# %%
dados['droga'].nunique()
# Out:
# 3289

# %% [markdown]
# ### Desafio 05: Procurar na documentação o método query(pandas)

# %% [markdown]
# ### Desafio 06: Gráfico bonitos. (Matplotlib.pyplot)

# %%
dados['tempo'].value_counts().plot.bar(color='#DC7CAF')
plt.title('Tempo')
# Out:
# Text(0.5, 1.0, 'Tempo')

# %%
dados['tempo'].value_counts().plot.pie()

# %% [markdown]
# ### Desafio 07: Renomear as colunas tirando o hífen.

# %% [markdown]
# ### Desafio 08: Resumo do que você aprendeu com os dados.

# %% [markdown]
# - No tratamento há uma desproporção: 93% com droga e 7% com controle. (dados aproximados)
# - É mais convencional utilizar gráficos de barras
# - Foram testadas 3289 drogas.
