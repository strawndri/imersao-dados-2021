# %% [markdown]
# <a href="https://colab.research.google.com/github/strawndri/imersao-dados-2021/blob/main/Aula_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação das Bibliotecas

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Importação dos Dados

# %%
url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %% [markdown]
# ### Análise e Modificação

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True) #modifica permanentemente

# %%
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
dados.describe() # estatísticas
# Out:
#               tempo           g-0  ...          c-98          c-99
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean      48.020156      0.248366  ...     -0.470252     -0.301505
# std       19.402807      1.393399  ...      1.834828      1.407918
# min       24.000000     -5.513000  ...    -10.000000    -10.000000
# 25%       24.000000     -0.473075  ...     -0.592600     -0.562900
# 50%       48.000000     -0.008850  ...      0.014000     -0.019500
# 75%       72.000000      0.525700  ...      0.461275      0.438650
# max       72.000000     10.000000  ...      3.111000      3.805000
#
# [8 rows x 873 columns]

# %%
dados.loc[:, 'g-0':'g-771'].describe()
# Out:
#                 g-0           g-1  ...         g-770         g-771
# count  23814.000000  23814.000000  ...  23814.000000  23814.000000
# mean       0.248366     -0.095684  ...     -0.219210      0.101524
# std        1.393399      0.812363  ...      1.326193      1.417674
# min       -5.513000     -5.737000  ...    -10.000000    -10.000000
# 25%       -0.473075     -0.562200  ...     -0.554400     -0.523800
# 50%       -0.008850     -0.046600  ...      0.028700     -0.006500
# 75%        0.525700      0.403075  ...      0.496400      0.536950
# max       10.000000      5.039000  ...     10.000000     10.000000
#
# [8 rows x 772 columns]

# %% [markdown]
# ### Gráfico

# %%
principais_compostos = dados['composto'].value_counts().index[:5]
principais_compostos

# %%
compostos_frequentes = dados.query('composto in @principais_compostos') # filtrando dados

# %%
plt.figure(figsize=(8,6)) # tamanho da imagem

sns.set() # rodar as configurações de imagem do seaborn
ax = sns.countplot(x = 'composto', data=compostos_frequentes, order=principais_compostos)
ax.set_title('5 Principais Compostos')
plt.show()

# %% [markdown]
# ### Histograma

# %%
# histograma do g-0
plt.figure(figsize=(16,8))
histograma_g0 = dados['g-0'].hist(bins=30)
histograma_g0.set_title('Grau de Expressões do Gene 0')

# %%
# histograma da média entre todos os genes
plt.figure(figsize=(16,8))
genes = dados.loc[:, 'g-0':'g-771'].describe().T
genes['mean'].hist(bins=30)

# %% [markdown]
# ### Boxplot

# %%
sns.boxplot(x='g-0',data=dados)

# %% [markdown]
# ## Desafios

# %% [markdown]
# ### Desafio 01: Ordenar os valores do gráfico dos principais compostos. (countplot)

# %% [markdown]
# ### Desafio 02: Melhorar a visualização.

# %% [markdown]
# ### Desafio 03: Plotar os histogramas com o seaborn.

# %% [markdown]
# ### Desafio 04: Estudar sobre as estatísticas retornadas do método .describe()

# %% [markdown]
# ### Desafio 05: Refletir sobre a manipulação do tamanho das visualizações.

# %% [markdown]
# ### Desafio 06: Fazer outras análises com o boxplot e histograma.

# %% [markdown]
# ### Desafio 07: Resumo do que você aprendeu com os dados.

# %% [markdown]
# A partir da aula conheci uma nova biblioteca chamada **seaborn** (além da matplotlib, a qual já tinha conhecimento). Utilizamos vários métodos da seaborn a fim de trabalhar com estatísticas gráficas, como o boxplot, que mostrou a mediana das expressões gênicas (0).
# Ademais, aprendi sobre Histogramas e sua importância em análises de dados.
